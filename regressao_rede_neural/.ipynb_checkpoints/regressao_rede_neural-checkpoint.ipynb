# %% [markdown]
# ## REDES NEURAIS
#
# https://github.com/alura-cursos/redes-neurais
#
# Base de dados: https://github.com/alura-cursos/redes-neurais/archive/allanspadini-aula-1.zip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dados = pd.read_csv('./data/Bicicletas.csv')
dados.head()
# Out:
#    clima  temperatura  bicicletas_alugadas
# 0      2     0.363625                  985
# 1      2     0.353739                  801
# 2      1     0.189405                 1349
# 3      1     0.212122                 1562
# 4      1     0.229270                 1600

# %%
def plotar_dados(x, y, label_eixoX, indices=None):

    if indices is not None:
        plt.xticks(indices, fontsize=14)

    plt.rcParams.update({'font.size': 14})
    plt.scatter(x, y)
    plt.xlabel(label_eixoX)
    plt.ylabel('bicicletas_alugadas')



plotar_dados(dados['temperatura'], dados['bicicletas_alugadas'], label_eixoX='temperatura')

# %%
plotar_dados(dados['clima'], dados['bicicletas_alugadas'], label_eixoX='clima', indices=[1,2,3])

# %% [markdown]
# ## Normalização dos dados

# %%
y = dados['bicicletas_alugadas'].values
x = dados[['clima', 'temperatura']].values

# %%
X = x/np.amax(x, axis=0)
y_max = np.amax(y)
Y = y/y_max

# %% [markdown]
# ## Criando a estrutura da rede

# %%
sigmoid = lambda valor: 1 / (1 + np.exp(-valor))
relu = lambda valor: np.maximum(0,valor)

# %%
arquitetura_1 = [{
    
  'dim_entrada': 2, # duas variáveis preditoras
  'dim_saida': 4, #camada_oculta_proximo_nivel_profundidade_rede
  'ativacao': 'relu' #funcao_ativação  
    
},

{
    
  'dim_entrada':4, # variáveis camada oculta (4 neurônios)
  'dim_saida':1, #camada_oculta_proximo_nivel_profundidade_rede
  'ativacao':'sigmoid' #funcao_ativação  
    
}


]

# %%
def inicia_camadas(arquitetura, seed=99):
    np.random.seed(seed)
    
    numero_camadas_rede = len(arquitetura_1)

    valores_parametros = {}
    
    for i, camada in enumerate(arquitetura_1):
        indice_camada  = i+1
        
        tamanho_camada_entrada = camada['dim_entrada']
        tamanho_camada_saida = camada['dim_saida']
        
        valores_parametros['Pesos' + str(indice_camada)] = np.random.randn(tamanho_camada_saida
                                                                               , tamanho_camada_entrada)
        
        valores_parametros['bias' + str(indice_camada)] = np.random.randn(tamanho_camada_saida, 1) * 0.1

    return valores_parametros

# %%
def propagar_camada(ativada_anterior, pesos_atual, bias_atual, ativacao='relu'):
    
    Saida_atual = np.dot(pesos_atual, ativada_anterior) + bias_atual
    
    if ativacao is 'relu':
        funcao_ativacao = relu
    elif ativacao is 'sigmoid':
        funcao_ativacao = sigmoid
        
    return funcao_ativacao(Saida_atual), Saida_atual

# %%
def propaga_total(X, valores_parametros, arquitetura):
    
    memoria = {}
    ativacao_atual = X
    
    for i, camada in enumerate(arquitetura): 
        
        indice_camada = i+1
        ativacao_anterior = ativacao_atual
        funcao_ativacao_atual = camada['ativacao']
        pesos_atual = valores_parametros['Pesos'+str(indice_camada)]
        bias_atual = valores_parametros['bias'+str(indice_camada)]
        
        ativado_atual, saida_atual = propagar_camada(ativacao_anterior, 
                                                     pesos_atual, bias_atual, 
                                                     funcao_ativacao_atual)
        
        memoria['Anterior'+str(i)] = ativacao_anterior
        memoria['Saida'+str(indice_camada)] = saida_atual
        
        return ativacao_atual, memoria

# %%
valores_parametros = inicia_camadas(arquitetura_1)

y_estimado, memoria = propaga_total(np.transpose(X), valores_parametros, arquitetura_1)
